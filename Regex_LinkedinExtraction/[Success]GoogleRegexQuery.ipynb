# %%
import json
import os
from dotenv import load_dotenv
from pymongo import MongoClient
from googlesearch import search

# Load environment variables
load_dotenv()

# Get MongoDB URI from .env file
mongodb_uri = os.getenv('13F_MongoDB_URI')

# Connect to MongoDB
client = MongoClient(mongodb_uri)
db = client['13f_filings']
collection = db['investment_firms']

def search_company(company_name):
    query = f"{company_name} site:linkedin.com"
    search_results = []
    
    try:
        for j in search(query, tld="co.in", num=10, stop=10, pause=2):
            if "https://www.linkedin.com/in" in j:
                search_results.append(j)
    except Exception as e:
        print(f"Error searching for {company_name}: {str(e)}")
    
    return search_results

def process_company(company_name):
    linkedin_links = search_company(company_name)
    return linkedin_links

def main():
    # Extract firm names from the collection
    firm_names = [doc['Firm Name'] for doc in collection.find({}, {'Firm Name': 1, '_id': 0}) if 'Firm Name' in doc]

    # Dictionary to store all results
    all_results = {}

    # Process each company
    for company_name in firm_names:
        linkedin_links = process_company(company_name)
        all_results[company_name] = linkedin_links
        
        print(f"Processed {company_name}")

    # Save all results to a single JSON file
    with open('all_companies_linkedin_links.json', 'w') as f:
        json.dump(all_results, f, indent=2)

    print("All results saved to all_companies_linkedin_links.json")

    # Close the MongoDB connection
    client.close()

if __name__ == "__main__":
    main()
# Out:
# Processed Creekside Partners
# Processed Gordian Capital Singapore Pte Ltd
# Processed Brown Financial Advisors
# Processed NCP Inc.
# Processed SW Investment Management LLC
# Processed Centennial Bank AR
# Processed Mendon Capital Advisors Corp
# Processed Pensioenfonds Rail & OV
# Processed Strategic Investment Solutions Inc. IL
# Processed University of Texas Texas AM Investment Management Co.
# Processed SRN Advisors LLC
# Processed Cowen Investment Management LLC
# Processed Maven Securities LTD
# Processed Gibson Wealth Advisors LLC
# Processed RiverFront Investment Group LLC
# Processed Heritage Oak Wealth Advisors LLC
# Processed Kestra Investment Management LLC
# Processed Sycomore Asset Management
# Processed Birmingham Capital Management Co. Inc. AL
# Processed Farmers National Bank
# Processed Souders Financial Advisors
# Processed Logos Global Management LP
# Processed Clearbridge Investments LLC
# Processed Carrera Capital Advisors
# Processed New Wave Wealth Advisors LLC
# Processed Dana Investment Advisors Inc.
# Processed New Century Financial Group LLC
# Processed Custom Portfolio Group LLC
# Processed KPP Advisory Services LLC
# Processed Teachers Retirement System of The State of Kentucky
# Processed Allianz Investment Management U.S. LLC
# Processed Wealthquest Corp
# Processed BRIGHT VALLEY CAPITAL Ltd
# Processed Ariadne Wealth Management LP
# Processed Founders Financial Alliance LLC
# Processed SPX Gestao de Recursos Ltda
# Processed Delphi Management Inc. MA
# Processed Aristides Capital LLC
# Processed Somnio Financial Group LLC
# Processed Orleans Capital Management Corp LA
# Processed Troy Asset Management Ltd
# Processed PVG Asset Management Corp
# Processed Cypress Capital LLC
# Processed Aurora Investment Counsel
# Processed Cetera Investment Advisers
# Processed Aldebaran Financial Inc.
# Processed Kanen Wealth Management LLC
# Processed KGH Ltd
# Processed LHM Inc.
# Processed 3Chopt Investment Partners LLC
# Processed McGinn Penninger Investment Management Inc.
# Processed SPC Financial Inc.
# Processed Heartland Bank & Trust Co
# Processed Greenvale Capital LLP
# Processed Advisory Alpha LLC
# Processed Ted Buchan & Co
# Processed Graham Capital Wealth Management LLC
# Processed Granite Bay Wealth Management LLC
# Processed IMS Capital Management
# Processed Regency Capital Management Inc. DE
# Processed Stonepine Capital Management LLC
# Processed Truist Financial Corp
# Processed Nantahala Capital Management LLC
# Processed Pathway Financial Advisers LLC
# Processed HFG Wealth Management LLC
# Processed Novo Holdings A S
# Processed Next Capital Management LLC
# Processed Senator Investment Group LP
# Processed Garde Capital Inc.
# Processed HWG Holdings LP
# Processed Point72 Asset Management L.P.
# Processed Old North State Trust LLC
# Processed Fiera Capital Corp
# Processed EP Wealth Advisors LLC
# Processed Hershey Financial Advisers LLC
# Processed Chase Investment Counsel Corp
# Processed Brown Shipley& Co Ltd
# Processed Kimelman & Baird LLC
# Processed Brandes Investment Partners LP
# Processed Lynx1 Capital Management LP
# Processed B. Riley Wealth Advisors Inc.
# Processed Connective Capital Management LLC
# Processed CMG Global Holdings LLC
# Processed Newport Capital Group LLC
# Processed Gateway Wealth Partners LLC
# Processed Perceptive Advisors LLC
# Processed Traction Financial Partners LLC
# Processed Core Alternative Capital
# Processed Ironwood Investment Management LLC
# Processed Kampmann Melissa S.
# Processed Wallace Capital Management Inc.
# Processed Saratoga Research & Investment Management
# Processed Ecofi Investissements SA
# Processed Seaport Global Advisors LLC
# Processed Capital Impact Advisors LLC
# Processed Progeny 3 Inc.
# Processed Second Line Capital LLC
# Processed Covington Investment Advisors Inc.
# Processed Teewinot Capital Advisers L.L.C.
# Processed Invst LLC
# All results saved to all_companies_linkedin_links.json
